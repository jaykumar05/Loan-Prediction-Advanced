# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from numpy import loadtxt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix

# %%
# Reading data
loan_data = pd.read_csv("/content/loan_data_ADA_assignment.csv")
loan_data = loan_data.replace(r'^\s*$', np.nan, regex=True)

# %%
# Dropping non-required columns
loan_data.drop(columns=['id', 'member_id', 'sub_grade', 'emp_title', 'emp_length', 'issue_d', 'pymnt_plan', 'desc', 'purpose', 'title', 'zip_code', 'addr_state', 'inq_last_6mths', 'earliest_cr_line', 'mths_since_last_delinq', 'mths_since_last_record', 'total_rec_late_fee', 'recoveries', 'collection_recovery_fee', 'last_pymnt_d', 'policy_code', 'last_credit_pull_d', 'acc_now_delinq', 'next_pymnt_d', 'home_ownership', 'collections_12_mths_ex_med', 'mths_since_last_major_derog', 'total_credit_rv'], inplace=True)

# %%
# Converting categorical variables to factors
loan_data['grade'] = loan_data['grade'].map({'A': 1, 'B': 2, 'C': 3, 'D': 4, 'E': 5, 'F': 6, 'G': 7})

# %%
# One-hot encoding for categorical variables
loan_data = pd.get_dummies(loan_data, columns=['verification_status', 'loan_status'])

# %%
# Handling missing values by replacing with mode
loan_data['tot_coll_amt'].fillna(loan_data['tot_coll_amt'].mode()[0], inplace=True)
loan_data['tot_cur_bal'].fillna(loan_data['tot_cur_bal'].mode()[0], inplace=True)

# Converting and replacing %
loan_data['revol_util'] = loan_data['revol_util'].fillna(0)
loan_data['revol_util'] = loan_data['revol_util'].astype(str).str.replace('%', '').astype(float)
loan_data['revol_util'] = loan_data['revol_util'].astype(str).str.replace('%', '').astype(float).astype(int)
# Out:
# <ipython-input-12-fd53401a1531>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   loan_data['tot_coll_amt'].fillna(loan_data['tot_coll_amt'].mode()[0], inplace=True)
# <ipython-input-12-fd53401a1531>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   loan_data['tot_cur_bal'].fillna(loan_data['tot_cur_bal'].mode()[0], inplace=True)

# %%
#Standardizing using z-scores
columns_to_standardize = [
    'loan_amnt', 'funded_amnt', 'funded_amnt_inv','int_rate', 'installment',
    'annual_inc', 'dti', 'revol_bal', 'total_pymnt', 'total_pymnt_inv',
    'total_rec_prncp', 'total_rec_int', 'last_pymnt_amnt', 'tot_cur_bal',
    'term', 'open_acc', 'revol_util', 'total_acc', 'tot_coll_amt'
]

# Initialize the StandardScaler
scaler = StandardScaler()

# Loop through columns and replace each one with standardized values
for col in columns_to_standardize:
    col_values = loan_data[[col]]
    standardized_values = scaler.fit_transform(col_values)
    loan_data[col] = standardized_values.flatten()  # Overwrite original column with standardized values

# %%
# Splitting data into training and test sets
X = loan_data.drop(columns=['loan_is_bad']).astype('float')
y = loan_data['loan_is_bad'].astype('float')
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

over_sampler = SMOTE(sampling_strategy=0.5, random_state=1)
under_sampler = RandomUnderSampler(sampling_strategy=0.5, random_state=1)
X_train_over, y_train_over = over_sampler.fit_resample(X_train, y_train)
X_train_balanced, y_train_balanced = under_sampler.fit_resample(X_train_over, y_train_over)
X_train_balanced, y_train_balanced = under_sampler.fit_resample(X_train, y_train)

train_dataset = tf.data.Dataset.from_tensor_slices((X_train_balanced, y_train_balanced))
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test))

# Encoding target variable
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
y_test = label_encoder.transform(y_test)

# %%
# One-hot encoding for target variable
#one_hot_encoder = OneHotEncoder()
#y_train_balanced_encoded_one_hot = one_hot_encoder.fit_transform(y_train.reshape(-1, 1)).toarray()
#y_test_encoded_one_hot = one_hot_encoder.transform(y_test.reshape(-1, 1)).toarray()

train_batch = train_dataset.batch(500)
features, labels = next(iter(train_batch))
#features

model = tf.keras.Sequential([
    tf.keras.layers.Dense(32, activation=tf.nn.relu, input_shape=(32,)),
    tf.keras.layers.Dense(16, activation=tf.nn.relu),
    tf.keras.layers.Dense(16, activation=tf.nn.relu),
    tf.keras.layers.Dense(8, activation=tf.nn.relu),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.01,  weight_decay=0.5, momentum = 0.9),
              loss=tf.keras.losses.BinaryCrossentropy(), #loss function as cross entropy
              metrics=['accuracy', 'precision', 'recall'])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
#Model training
model.fit(features, labels, epochs=100)

test_batch = test_dataset.batch(1000)  # the whole dataset
test_features, test_labels = next(iter(test_batch))

y_pred = model.predict(test_features)
# Out:
# Epoch 1/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.2854 - loss: 0.8381 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 2/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.4368 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 3/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.2779 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 4/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.1939 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 5/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.1456 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 6/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.1134 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 7/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0900 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 8/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0728 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 9/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0605 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 10/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0514 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 11/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0448 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 12/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0407 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 13/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0375 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 14/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0347 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 15/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0331 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 16/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0315 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 17/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0302 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 18/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0286 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 19/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0285 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 20/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0278 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 21/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0272 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 22/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0259 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 23/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0250 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 24/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0245 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 25/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0246 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 26/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0238 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 27/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0234 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 28/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0236 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 29/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0228 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 30/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0225 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 31/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0218 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 32/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0219 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 33/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0219 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 34/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0209 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 35/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0208 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 36/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0210 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 37/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0208 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 38/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0200 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 39/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0200 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 40/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0199 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 41/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0195 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 42/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0199 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 43/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0191 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 44/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0194 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 45/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0193 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 46/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0195 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 47/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0193 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 48/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0185 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 49/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0192 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 50/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0191 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 51/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0186 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 52/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0191 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 53/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0186 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 54/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0192 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 55/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0186 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 56/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0190 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 57/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0188 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 58/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0184 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 59/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0188 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 60/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0178 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 61/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0182 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 62/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0181 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 63/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0188 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 64/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0183 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 65/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0186 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 66/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0186 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 67/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0180 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 68/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0184 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 69/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0183 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 70/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0180 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 71/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0177 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 72/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0182 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 73/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0178 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 74/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0177 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 75/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0177 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 76/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0180 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 77/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0174 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 78/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0178 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 79/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0177 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 80/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0175 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 81/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0179 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 82/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0179 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 83/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0175 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 84/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0185 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 85/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0175 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 86/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0174 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 87/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0175 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 88/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0174 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 89/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0181 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 90/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0173 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 91/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0181 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 92/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0174 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 93/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0179 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 94/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0176 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 95/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0175 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 96/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0176 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 97/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0181 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 98/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0178 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 99/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0178 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 100/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0180 - precision: 0.0000e+00 - recall: 0.0000e+00
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step

# %%
# Convert probabilities to binary predictions
y_pred_binary = (y_pred > 0.1).astype(int)

# Flatten the true labels if they are not already flattened
test_labels_flat = np.ravel(test_labels)

# Compute precision, recall, and F1-score
precision = precision_score(test_labels_flat, y_pred_binary)
recall = recall_score(test_labels_flat, y_pred_binary)
#f1 = f1_score(test_labels_flat, y_pred_binary)

print('Precision:', precision)
print('Recall:', recall)
#print('F1-score:', f1)

for pred, real in zip(y_pred, test_labels):
   print(f"Predicted: {pred[0]};    Real: {real}")

#print confusion matrix
conf_matrix = confusion_matrix(test_labels_flat, y_pred_binary)
print('Confusion Matrix:')
print(conf_matrix)

# Evaluate the model on the test set
test_loss, test_accuracy, test_precision, test_recall = model.evaluate(test_features, test_labels, verbose=2)

print('\nTest Accuracy:', test_accuracy)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Precision: 0.0
# Recall: 0.0
# Predicted: 0.04858645051717758;    Real: 0.0
# Predicted: 0.03714752569794655;    Real: 0.0
# Predicted: 0.029822418466210365;    Real: 0.0
# Predicted: 0.02150643989443779;    Real: 0.0
# Predicted: 0.006924881599843502;    Real: 0.0
# Predicted: 0.031906746327877045;    Real: 0.0
# Predicted: 0.020370911806821823;    Real: 0.0
# Predicted: 0.008991843089461327;    Real: 1.0
# Predicted: 0.0120429378002882;    Real: 0.0
# Predicted: 0.02139572985470295;    Real: 0.0
# Predicted: 0.011918429285287857;    Real: 0.0
# Predicted: 0.012234261259436607;    Real: 0.0
# Predicted: 0.006330637726932764;    Real: 0.0
# Predicted: 0.010951547883450985;    Real: 0.0
# Predicted: 0.021037571132183075;    Real: 0.0
# Predicted: 0.03131885826587677;    Real: 0.0
# Predicted: 0.021650806069374084;    Real: 0.0
# Predicted: 0.020500175654888153;    Real: 0.0
# Predicted: 0.003269077045843005;    Real: 0.0
# Predicted: 0.011495153419673443;    Real: 0.0
# Predicted: 0.020113039761781693;    Real: 0.0
# Predicted: 0.011637803167104721;    Real: 0.0
# Predicted: 0.0163295716047287;    Real: 0.0
# Predicted: 0.03445635735988617;    Real: 0.0
# Predicted: 0.007149412762373686;    Real: 1.0
# Predicted: 0.023883070796728134;    Real: 1.0
# Predicted: 0.03136412426829338;    Real: 0.0
# Predicted: 0.020601404830813408;    Real: 0.0
# Predicted: 0.029128072783350945;    Real: 0.0
# Predicted: 0.019479557871818542;    Real: 0.0
# Predicted: 0.02050379477441311;    Real: 0.0
# Predicted: 0.011498005129396915;    Real: 0.0
# Predicted: 0.012969177216291428;    Real: 0.0
# Predicted: 0.018433306366205215;    Real: 0.0
# Predicted: 0.030240081250667572;    Real: 1.0
# Predicted: 0.021679077297449112;    Real: 0.0
# Predicted: 0.011786965653300285;    Real: 0.0
# Predicted: 0.012342102825641632;    Real: 0.0
# Predicted: 0.010179579257965088;    Real: 0.0
# Predicted: 0.03469456732273102;    Real: 0.0
# Predicted: 0.04194594547152519;    Real: 0.0
# Predicted: 0.0072483764961361885;    Real: 0.0
# Predicted: 0.02054123394191265;    Real: 0.0
# Predicted: 0.013617056421935558;    Real: 0.0
# Predicted: 0.01933414302766323;    Real: 0.0
# Predicted: 0.004818282555788755;    Real: 0.0
# Predicted: 0.030168386176228523;    Real: 0.0
# Predicted: 0.006006456445902586;    Real: 0.0
# Predicted: 0.0025482785422354937;    Real: 0.0
# Predicted: 0.025993911549448967;    Real: 0.0
# Predicted: 0.019402004778385162;    Real: 1.0
# Predicted: 0.009931780397891998;    Real: 1.0
# Predicted: 0.01084019336849451;    Real: 0.0
# Predicted: 0.020517196506261826;    Real: 0.0
# Predicted: 0.013178881257772446;    Real: 0.0
# Predicted: 0.018928157165646553;    Real: 0.0
# Predicted: 0.011218448169529438;    Real: 0.0
# Predicted: 0.010655743069946766;    Real: 0.0
# Predicted: 0.01961950585246086;    Real: 0.0
# Predicted: 0.010176154784858227;    Real: 0.0
# Predicted: 0.03185747563838959;    Real: 0.0
# Predicted: 0.012047115713357925;    Real: 0.0
# Predicted: 0.006720123812556267;    Real: 0.0
# Predicted: 0.046568144112825394;    Real: 0.0
# Predicted: 0.001880528638139367;    Real: 1.0
# Predicted: 0.022936224937438965;    Real: 0.0
# Predicted: 0.01156656350940466;    Real: 0.0
# Predicted: 0.018597356975078583;    Real: 0.0
# Predicted: 0.04473288357257843;    Real: 0.0
# Predicted: 0.02065271884202957;    Real: 0.0
# Predicted: 0.029606139287352562;    Real: 0.0
# Predicted: 0.013876045122742653;    Real: 0.0
# Predicted: 0.018698038533329964;    Real: 0.0
# Predicted: 0.023204315453767776;    Real: 0.0
# Predicted: 0.007441775873303413;    Real: 0.0
# Predicted: 0.005795804318040609;    Real: 0.0
# Predicted: 0.01852189376950264;    Real: 0.0
# Predicted: 0.01696925237774849;    Real: 0.0
# Predicted: 0.006274126004427671;    Real: 0.0
# Predicted: 0.008119829930365086;    Real: 0.0
# Predicted: 0.003112715668976307;    Real: 1.0
# Predicted: 0.019645174965262413;    Real: 0.0
# Predicted: 0.00738110113888979;    Real: 0.0
# Predicted: 0.01896783895790577;    Real: 0.0
# Predicted: 0.006655869539827108;    Real: 0.0
# Predicted: 0.009933984838426113;    Real: 1.0
# Predicted: 0.010049593634903431;    Real: 1.0
# Predicted: 0.00691324332728982;    Real: 0.0
# Predicted: 0.019789913669228554;    Real: 0.0
# Predicted: 0.018420172855257988;    Real: 0.0
# Predicted: 0.011498736217617989;    Real: 0.0
# Predicted: 0.022578876465559006;    Real: 0.0
# Predicted: 0.011584741994738579;    Real: 1.0
# Predicted: 0.011973180808126926;    Real: 0.0
# Predicted: 0.05216795951128006;    Real: 0.0
# Predicted: 0.015407404862344265;    Real: 1.0
# Predicted: 0.017967581748962402;    Real: 0.0
# Predicted: 0.019361386075615883;    Real: 0.0
# Predicted: 0.010514313355088234;    Real: 0.0
# Predicted: 0.005776654463261366;    Real: 1.0
# Predicted: 0.011571275070309639;    Real: 0.0
# Predicted: 0.011328751221299171;    Real: 1.0
# Predicted: 0.01836935617029667;    Real: 0.0
# Predicted: 0.01976008526980877;    Real: 0.0
# Predicted: 0.01046204473823309;    Real: 0.0
# Predicted: 0.017649464309215546;    Real: 1.0
# Predicted: 0.011101426556706429;    Real: 0.0
# Predicted: 0.032017000019550323;    Real: 0.0
# Predicted: 0.01204346027225256;    Real: 0.0
# Predicted: 0.011990053579211235;    Real: 0.0
# Predicted: 0.015474308282136917;    Real: 1.0
# Predicted: 0.01161024160683155;    Real: 0.0
# Predicted: 0.029325898736715317;    Real: 1.0
# Predicted: 0.01991586945950985;    Real: 0.0
# Predicted: 0.00825364701449871;    Real: 0.0
# Predicted: 0.03223831579089165;    Real: 0.0
# Predicted: 0.011241942644119263;    Real: 0.0
# Predicted: 0.02185152843594551;    Real: 0.0
# Predicted: 0.014662600122392178;    Real: 1.0
# Predicted: 0.010936059057712555;    Real: 0.0
# Predicted: 0.03249116241931915;    Real: 0.0
# Predicted: 0.03694213181734085;    Real: 0.0
# Predicted: 0.019328592345118523;    Real: 0.0
# Predicted: 0.020264524966478348;    Real: 0.0
# Predicted: 0.009951910935342312;    Real: 0.0
# Predicted: 0.03448928892612457;    Real: 0.0
# Predicted: 0.018312692642211914;    Real: 0.0
# Predicted: 0.01121607981622219;    Real: 0.0
# Predicted: 0.012641079723834991;    Real: 0.0
# Predicted: 0.018213415518403053;    Real: 0.0
# Predicted: 0.003810057183727622;    Real: 0.0
# Predicted: 0.007489203941076994;    Real: 0.0
# Predicted: 0.018714407458901405;    Real: 0.0
# Predicted: 0.02074851281940937;    Real: 0.0
# Predicted: 0.03739675506949425;    Real: 0.0
# Predicted: 0.012778639793395996;    Real: 0.0
# Predicted: 0.02478180080652237;    Real: 0.0
# Predicted: 0.02262716367840767;    Real: 0.0
# Predicted: 0.010977623984217644;    Real: 0.0
# Predicted: 0.019982798025012016;    Real: 0.0
# Predicted: 0.004293243866413832;    Real: 0.0
# Predicted: 0.01673244498670101;    Real: 0.0
# Predicted: 0.012224278412759304;    Real: 0.0
# Predicted: 0.005529157351702452;    Real: 0.0
# Predicted: 0.020620068535208702;    Real: 0.0
# Predicted: 0.017922556027770042;    Real: 1.0
# Predicted: 0.019843338057398796;    Real: 1.0
# Predicted: 0.019866295158863068;    Real: 0.0
# Predicted: 0.016225408762693405;    Real: 0.0
# Predicted: 0.02367296628654003;    Real: 0.0
# Predicted: 0.014975912868976593;    Real: 0.0
# Predicted: 0.02651544287800789;    Real: 0.0
# Predicted: 0.01214869786053896;    Real: 0.0
# Predicted: 0.03489294275641441;    Real: 0.0
# Predicted: 0.013100812211632729;    Real: 0.0
# Predicted: 0.008159431628882885;    Real: 0.0
# Predicted: 0.005973723251372576;    Real: 0.0
# Predicted: 0.017090924084186554;    Real: 0.0
# Predicted: 0.02230452001094818;    Real: 0.0
# Predicted: 0.01710343174636364;    Real: 0.0
# Predicted: 0.01113196648657322;    Real: 0.0
# Predicted: 0.005260859616100788;    Real: 1.0
# Predicted: 0.031619470566511154;    Real: 0.0
# Predicted: 0.015394448302686214;    Real: 1.0
# Predicted: 0.025324838235974312;    Real: 1.0
# Predicted: 0.019093291833996773;    Real: 0.0
# Predicted: 0.019602114334702492;    Real: 0.0
# Predicted: 0.006861437577754259;    Real: 0.0
# Predicted: 0.03266296535730362;    Real: 0.0
# Predicted: 0.011541089043021202;    Real: 1.0
# Predicted: 0.012139533646404743;    Real: 0.0
# Predicted: 0.011245122179389;    Real: 0.0
# Predicted: 0.006100337021052837;    Real: 0.0
# Predicted: 0.013166899792850018;    Real: 1.0
# Predicted: 0.04133336991071701;    Real: 0.0
# Predicted: 0.018241634592413902;    Real: 0.0
# Predicted: 0.01958097703754902;    Real: 0.0
# Predicted: 0.014643426984548569;    Real: 0.0
# Predicted: 0.02672949619591236;    Real: 1.0
# Predicted: 0.011210433207452297;    Real: 0.0
# Predicted: 0.01603740081191063;    Real: 1.0
# Predicted: 0.02714981697499752;    Real: 0.0
# Predicted: 0.01054544746875763;    Real: 0.0
# Predicted: 0.008356079459190369;    Real: 1.0
# Predicted: 0.009043619967997074;    Real: 1.0
# Predicted: 0.015628766268491745;    Real: 1.0
# Predicted: 0.017890237271785736;    Real: 0.0
# Predicted: 0.004627086687833071;    Real: 0.0
# Predicted: 0.01936006359755993;    Real: 0.0
# Predicted: 0.0034617746714502573;    Real: 0.0
# Predicted: 0.019326388835906982;    Real: 0.0
# Predicted: 0.015318634919822216;    Real: 0.0
# Predicted: 0.007566498592495918;    Real: 0.0
# Predicted: 0.021003374829888344;    Real: 0.0
# Predicted: 0.03236423432826996;    Real: 0.0
# Predicted: 0.02900194562971592;    Real: 0.0
# Predicted: 0.010321998968720436;    Real: 0.0
# Predicted: 0.0070924311876297;    Real: 0.0
# Predicted: 0.01205373927950859;    Real: 0.0
# Predicted: 0.011995607987046242;    Real: 0.0
# Predicted: 0.02286580391228199;    Real: 0.0
# Predicted: 0.016971174627542496;    Real: 1.0
# Predicted: 0.011908404529094696;    Real: 0.0
# Predicted: 0.004019586835056543;    Real: 0.0
# Predicted: 0.026495855301618576;    Real: 0.0
# Predicted: 0.019066831097006798;    Real: 0.0
# Predicted: 0.005612811539322138;    Real: 0.0
# Predicted: 0.0031677884981036186;    Real: 0.0
# Predicted: 0.029519228264689445;    Real: 0.0
# Predicted: 0.01769382506608963;    Real: 0.0
# Predicted: 0.007686763536185026;    Real: 0.0
# Predicted: 0.0065443255007267;    Real: 0.0
# Predicted: 0.02089041844010353;    Real: 0.0
# Predicted: 0.019739599898457527;    Real: 0.0
# Predicted: 0.028586532920598984;    Real: 0.0
# Predicted: 0.009506874717772007;    Real: 0.0
# Predicted: 0.0065900967456400394;    Real: 0.0
# Predicted: 0.0067475708201527596;    Real: 0.0
# Predicted: 0.021724319085478783;    Real: 0.0
# Predicted: 0.002441606717184186;    Real: 0.0
# Predicted: 0.003042860422283411;    Real: 0.0
# Predicted: 0.027931978926062584;    Real: 0.0
# Predicted: 0.04906689375638962;    Real: 0.0
# Predicted: 0.02148728258907795;    Real: 0.0
# Predicted: 0.03402628004550934;    Real: 0.0
# Predicted: 0.021509813144803047;    Real: 0.0
# Predicted: 0.019116463139653206;    Real: 0.0
# Predicted: 0.01351883914321661;    Real: 1.0
# Predicted: 0.002283580834046006;    Real: 0.0
# Predicted: 0.012222724966704845;    Real: 0.0
# Predicted: 0.008999962359666824;    Real: 1.0
# Predicted: 0.021818580105900764;    Real: 0.0
# Predicted: 0.006254982203245163;    Real: 0.0
# Predicted: 0.012454736046493053;    Real: 0.0
# Predicted: 0.013621553778648376;    Real: 0.0
# Predicted: 0.025094198063015938;    Real: 1.0
# Predicted: 0.006291287951171398;    Real: 0.0
# Predicted: 0.03767123073339462;    Real: 0.0
# Predicted: 0.03491445258259773;    Real: 0.0
# Predicted: 0.008969892747700214;    Real: 1.0
# Predicted: 0.010893866419792175;    Real: 0.0
# Predicted: 0.01162699144333601;    Real: 0.0
# Predicted: 0.02292943000793457;    Real: 0.0
# Predicted: 0.029856804758310318;    Real: 0.0
# Predicted: 0.011224099434912205;    Real: 0.0
# Predicted: 0.004900041036307812;    Real: 0.0
# Predicted: 0.028738966211676598;    Real: 0.0
# Predicted: 0.009501267224550247;    Real: 1.0
# Predicted: 0.021799802780151367;    Real: 0.0
# Predicted: 0.04564037173986435;    Real: 1.0
# Predicted: 0.0346870943903923;    Real: 0.0
# Predicted: 0.028288397938013077;    Real: 0.0
# Predicted: 0.02126218006014824;    Real: 0.0
# Predicted: 0.01203692052513361;    Real: 0.0
# Predicted: 0.01854087971150875;    Real: 0.0
# Predicted: 0.011029517278075218;    Real: 0.0
# Predicted: 0.011178811080753803;    Real: 0.0
# Predicted: 0.011514187790453434;    Real: 0.0
# Predicted: 0.022633640095591545;    Real: 0.0
# Predicted: 0.016625110059976578;    Real: 1.0
# Predicted: 0.023365257307887077;    Real: 0.0
# Predicted: 0.01982741989195347;    Real: 0.0
# Predicted: 0.005342103075236082;    Real: 1.0
# Predicted: 0.021761439740657806;    Real: 0.0
# Predicted: 0.011952248401939869;    Real: 0.0
# Predicted: 0.01961168460547924;    Real: 0.0
# Predicted: 0.007164844311773777;    Real: 0.0
# Predicted: 0.033129848539829254;    Real: 0.0
# Predicted: 0.015965234488248825;    Real: 0.0
# Predicted: 0.008192197419703007;    Real: 0.0
# Predicted: 0.031470805406570435;    Real: 0.0
# Predicted: 0.01245475560426712;    Real: 0.0
# Predicted: 0.022593380883336067;    Real: 0.0
# Predicted: 0.012628271244466305;    Real: 0.0
# Predicted: 0.029466940090060234;    Real: 0.0
# Predicted: 0.03184999153017998;    Real: 0.0
# Predicted: 0.020757729187607765;    Real: 0.0
# Predicted: 0.02399071305990219;    Real: 0.0
# Predicted: 0.00778866047039628;    Real: 0.0
# Predicted: 0.011144449934363365;    Real: 0.0
# Predicted: 0.020065581426024437;    Real: 0.0
# Predicted: 0.016738086938858032;    Real: 0.0
# Predicted: 0.003246370702981949;    Real: 0.0
# Predicted: 0.035204675048589706;    Real: 0.0
# Predicted: 0.021239805966615677;    Real: 0.0
# Predicted: 0.03582989051938057;    Real: 0.0
# Predicted: 0.01123503316193819;    Real: 0.0
# Predicted: 0.016637807711958885;    Real: 0.0
# Predicted: 0.021544916555285454;    Real: 1.0
# Predicted: 0.007247168570756912;    Real: 0.0
# Predicted: 0.008053209632635117;    Real: 0.0
# Predicted: 0.019191347062587738;    Real: 0.0
# Predicted: 0.011501663364470005;    Real: 0.0
# Predicted: 0.0065679848194122314;    Real: 0.0
# Predicted: 0.0216211024671793;    Real: 0.0
# Predicted: 0.02264849655330181;    Real: 0.0
# Predicted: 0.011477828025817871;    Real: 0.0
# Predicted: 0.011140473186969757;    Real: 0.0
# Predicted: 0.022456999868154526;    Real: 0.0
# Predicted: 0.006453588139265776;    Real: 0.0
# Predicted: 0.010601598769426346;    Real: 1.0
# Predicted: 0.011061425320804119;    Real: 0.0
# Predicted: 0.010150222107768059;    Real: 1.0
# Predicted: 0.013923325575888157;    Real: 0.0
# Predicted: 0.019204948097467422;    Real: 0.0
# Predicted: 0.02881167083978653;    Real: 0.0
# Predicted: 0.020602550357580185;    Real: 0.0
# Predicted: 0.019168050959706306;    Real: 0.0
# Predicted: 0.034328218549489975;    Real: 0.0
# Predicted: 0.018612941727042198;    Real: 0.0
# Predicted: 0.01861533895134926;    Real: 0.0
# Predicted: 0.016649138182401657;    Real: 1.0
# Predicted: 0.010432781651616096;    Real: 1.0
# Predicted: 0.003965185955166817;    Real: 0.0
# Predicted: 0.023122284561395645;    Real: 0.0
# Predicted: 0.011104971170425415;    Real: 0.0
# Predicted: 0.02940388023853302;    Real: 0.0
# Predicted: 0.04082735627889633;    Real: 1.0
# Predicted: 0.006681239698082209;    Real: 1.0
# Predicted: 0.022091470658779144;    Real: 0.0
# Predicted: 0.023195520043373108;    Real: 0.0
# Predicted: 0.02643487975001335;    Real: 0.0
# Predicted: 0.004959625191986561;    Real: 0.0
# Predicted: 0.003597225761041045;    Real: 0.0
# Predicted: 0.01068949606269598;    Real: 0.0
# Predicted: 0.02352074161171913;    Real: 0.0
# Predicted: 0.012908710166811943;    Real: 0.0
# Predicted: 0.0056459493935108185;    Real: 0.0
# Predicted: 0.010650119744241238;    Real: 0.0
# Predicted: 0.017604339867830276;    Real: 0.0
# Predicted: 0.023496966809034348;    Real: 0.0
# Predicted: 0.003966521937400103;    Real: 0.0
# Predicted: 0.022634979337453842;    Real: 0.0
# Predicted: 0.02829641103744507;    Real: 1.0
# Predicted: 0.012682938948273659;    Real: 0.0
# Predicted: 0.004885878413915634;    Real: 0.0
# Predicted: 0.01192078273743391;    Real: 0.0
# Predicted: 0.019091254100203514;    Real: 0.0
# Predicted: 0.01912914589047432;    Real: 0.0
# Predicted: 0.03374501317739487;    Real: 0.0
# Predicted: 0.01115255057811737;    Real: 1.0
# Predicted: 0.04875234141945839;    Real: 1.0
# Predicted: 0.04183737188577652;    Real: 0.0
# Predicted: 0.019938761368393898;    Real: 0.0
# Predicted: 0.01904374547302723;    Real: 0.0
# Predicted: 0.006984742358326912;    Real: 0.0
# Predicted: 0.019014397636055946;    Real: 0.0
# Predicted: 0.006167469080537558;    Real: 0.0
# Predicted: 0.011086182668805122;    Real: 0.0
# Predicted: 0.011532453820109367;    Real: 0.0
# Predicted: 0.029621142894029617;    Real: 1.0
# Predicted: 0.02999609149992466;    Real: 0.0
# Predicted: 0.022484976798295975;    Real: 0.0
# Predicted: 0.030366424471139908;    Real: 0.0
# Predicted: 0.002713028574362397;    Real: 0.0
# Predicted: 0.0024198477622121572;    Real: 0.0
# Predicted: 0.02635885216295719;    Real: 0.0
# Predicted: 0.03431307524442673;    Real: 1.0
# Predicted: 0.021614253520965576;    Real: 0.0
# Predicted: 0.03316245973110199;    Real: 0.0
# Predicted: 0.010970073752105236;    Real: 0.0
# Predicted: 0.02140825241804123;    Real: 0.0
# Predicted: 0.017772255465388298;    Real: 0.0
# Predicted: 0.02006636932492256;    Real: 0.0
# Predicted: 0.013757335022091866;    Real: 0.0
# Predicted: 0.020764272660017014;    Real: 0.0
# Predicted: 0.029868945479393005;    Real: 1.0
# Predicted: 0.014049438759684563;    Real: 0.0
# Predicted: 0.01298403088003397;    Real: 0.0
# Predicted: 0.006554616615176201;    Real: 0.0
# Predicted: 0.011064951308071613;    Real: 1.0
# Predicted: 0.03300642594695091;    Real: 0.0
# Predicted: 0.022589504718780518;    Real: 0.0
# Predicted: 0.029580364003777504;    Real: 1.0
# Predicted: 0.011352729983627796;    Real: 0.0
# Predicted: 0.030839305371046066;    Real: 0.0
# Predicted: 0.02341907098889351;    Real: 0.0
# Predicted: 0.019152626395225525;    Real: 0.0
# Predicted: 0.021739372983574867;    Real: 0.0
# Predicted: 0.028887087479233742;    Real: 1.0
# Predicted: 0.032341450452804565;    Real: 0.0
# Predicted: 0.011061280034482479;    Real: 0.0
# Predicted: 0.0073510645888745785;    Real: 0.0
# Predicted: 0.03570113331079483;    Real: 0.0
# Predicted: 0.03552432730793953;    Real: 0.0
# Predicted: 0.02399754896759987;    Real: 0.0
# Predicted: 0.03380291163921356;    Real: 0.0
# Predicted: 0.03193117678165436;    Real: 0.0
# Predicted: 0.0035803213249891996;    Real: 0.0
# Predicted: 0.010072574950754642;    Real: 0.0
# Predicted: 0.012560376897454262;    Real: 1.0
# Predicted: 0.007194966543465853;    Real: 0.0
# Predicted: 0.018551044166088104;    Real: 0.0
# Predicted: 0.02288229949772358;    Real: 0.0
# Predicted: 0.022003410384058952;    Real: 0.0
# Predicted: 0.011535444296896458;    Real: 0.0
# Predicted: 0.03823503106832504;    Real: 0.0
# Predicted: 0.01933976635336876;    Real: 0.0
# Predicted: 0.0043791127391159534;    Real: 0.0
# Predicted: 0.03271649032831192;    Real: 0.0
# Predicted: 0.010785152204334736;    Real: 0.0
# Predicted: 0.01090344786643982;    Real: 0.0
# Predicted: 0.01847156509757042;    Real: 0.0
# Predicted: 0.011879421770572662;    Real: 0.0
# Predicted: 0.01715727150440216;    Real: 0.0
# Predicted: 0.00700018834322691;    Real: 0.0
# Predicted: 0.019590580835938454;    Real: 0.0
# Predicted: 0.024828366935253143;    Real: 1.0
# Predicted: 0.031606387346982956;    Real: 0.0
# Predicted: 0.008703741244971752;    Real: 1.0
# Predicted: 0.021649908274412155;    Real: 0.0
# Predicted: 0.019158434122800827;    Real: 0.0
# Predicted: 0.011707847006618977;    Real: 0.0
# Predicted: 0.03173661231994629;    Real: 0.0
# Predicted: 0.013157950714230537;    Real: 0.0
# Predicted: 0.02030729316174984;    Real: 0.0
# Predicted: 0.019767798483371735;    Real: 1.0
# Predicted: 0.011614833027124405;    Real: 0.0
# Predicted: 0.010522114112973213;    Real: 0.0
# Predicted: 0.015530535019934177;    Real: 0.0
# Predicted: 0.011084913276135921;    Real: 1.0
# Predicted: 0.0055067879147827625;    Real: 0.0
# Predicted: 0.009488190524280071;    Real: 0.0
# Predicted: 0.020362256094813347;    Real: 0.0
# Predicted: 0.033101022243499756;    Real: 0.0
# Predicted: 0.020601961761713028;    Real: 0.0
# Predicted: 0.01149196270853281;    Real: 0.0
# Predicted: 0.030835315585136414;    Real: 1.0
# Predicted: 0.007265064865350723;    Real: 0.0
# Predicted: 0.021361250430345535;    Real: 0.0
# Predicted: 0.01169956848025322;    Real: 0.0
# Predicted: 0.03387392312288284;    Real: 0.0
# Predicted: 0.010240769013762474;    Real: 1.0
# Predicted: 0.0068894680589437485;    Real: 0.0
# Predicted: 0.02391105517745018;    Real: 0.0
# Predicted: 0.004165490623563528;    Real: 0.0
# Predicted: 0.015588073059916496;    Real: 1.0
# Predicted: 0.021181777119636536;    Real: 0.0
# Predicted: 0.032512784004211426;    Real: 0.0
# Predicted: 0.01236165501177311;    Real: 0.0
# Predicted: 0.02333919145166874;    Real: 0.0
# Predicted: 0.017636628821492195;    Real: 1.0
# Predicted: 0.0311066135764122;    Real: 1.0
# Predicted: 0.015778888016939163;    Real: 0.0
# Predicted: 0.017476947978138924;    Real: 1.0
# Predicted: 0.020218074321746826;    Real: 0.0
# Predicted: 0.03015720099210739;    Real: 0.0
# Predicted: 0.028830863535404205;    Real: 0.0
# Predicted: 0.032762426882982254;    Real: 0.0
# Predicted: 0.011645044200122356;    Real: 0.0
# Predicted: 0.019493605941534042;    Real: 0.0
# Predicted: 0.023283161222934723;    Real: 0.0
# Predicted: 0.010692969895899296;    Real: 0.0
# Predicted: 0.005119498819112778;    Real: 0.0
# Predicted: 0.036094557493925095;    Real: 0.0
# Predicted: 0.01975787803530693;    Real: 0.0
# Predicted: 0.012835253030061722;    Real: 0.0
# Predicted: 0.009971356950700283;    Real: 1.0
# Predicted: 0.03481534123420715;    Real: 0.0
# Predicted: 0.00719945365563035;    Real: 0.0
# Predicted: 0.03233536332845688;    Real: 0.0
# Predicted: 0.026313047856092453;    Real: 0.0
# Predicted: 0.011191806755959988;    Real: 0.0
# Predicted: 0.03162860870361328;    Real: 0.0
# Predicted: 0.021625662222504616;    Real: 0.0
# Predicted: 0.011510432697832584;    Real: 0.0
# Predicted: 0.005631213076412678;    Real: 0.0
# Predicted: 0.0037658896762877703;    Real: 0.0
# Predicted: 0.01505728904157877;    Real: 0.0
# Predicted: 0.017398932948708534;    Real: 0.0
# Predicted: 0.020732389762997627;    Real: 0.0
# Predicted: 0.02175901271402836;    Real: 0.0
# Predicted: 0.011539489962160587;    Real: 0.0
# Predicted: 0.005910755135118961;    Real: 0.0
# Predicted: 0.012106390669941902;    Real: 0.0
# Predicted: 0.02093687281012535;    Real: 0.0
# Predicted: 0.03272787109017372;    Real: 1.0
# Predicted: 0.027442142367362976;    Real: 0.0
# Predicted: 0.015141504816710949;    Real: 1.0
# Predicted: 0.012076110579073429;    Real: 0.0
# Predicted: 0.007086010184139013;    Real: 0.0
# Predicted: 0.011223210021853447;    Real: 0.0
# Predicted: 0.017678141593933105;    Real: 0.0
# Predicted: 0.01941429078578949;    Real: 0.0
# Predicted: 0.020475629717111588;    Real: 0.0
# Predicted: 0.026553897187113762;    Real: 0.0
# Predicted: 0.027554500848054886;    Real: 1.0
# Predicted: 0.032112691551446915;    Real: 0.0
# Predicted: 0.019996969029307365;    Real: 0.0
# Predicted: 0.00987777579575777;    Real: 1.0
# Predicted: 0.011080439202487469;    Real: 0.0
# Predicted: 0.006435101851820946;    Real: 0.0
# Predicted: 0.019179124385118484;    Real: 0.0
# Predicted: 0.016896478831768036;    Real: 0.0
# Predicted: 0.00848777499049902;    Real: 1.0
# Predicted: 0.03045143000781536;    Real: 0.0
# Predicted: 0.007316115312278271;    Real: 0.0
# Predicted: 0.012221749871969223;    Real: 0.0
# Predicted: 0.029445484280586243;    Real: 0.0
# Predicted: 0.00730520486831665;    Real: 0.0
# Predicted: 0.014528742991387844;    Real: 1.0
# Predicted: 0.006705377716571093;    Real: 0.0
# Predicted: 0.005161390174180269;    Real: 0.0
# Predicted: 0.011739903129637241;    Real: 0.0
# Predicted: 0.04120528697967529;    Real: 1.0
# Predicted: 0.018551912158727646;    Real: 0.0
# Predicted: 0.028883567079901695;    Real: 0.0
# Predicted: 0.007723443675786257;    Real: 1.0
# Predicted: 0.032957274466753006;    Real: 0.0
# Predicted: 0.020532075315713882;    Real: 0.0
# Predicted: 0.006687860004603863;    Real: 1.0
# Predicted: 0.012341841123998165;    Real: 0.0
# Predicted: 0.009897662326693535;    Real: 0.0
# Predicted: 0.03157607465982437;    Real: 0.0
# Predicted: 0.01174086518585682;    Real: 0.0
# Predicted: 0.025937607511878014;    Real: 1.0
# Predicted: 0.01963455229997635;    Real: 0.0
# Predicted: 0.022394027560949326;    Real: 0.0
# Predicted: 0.010542144067585468;    Real: 0.0
# Predicted: 0.012467705644667149;    Real: 0.0
# Predicted: 0.006294601131230593;    Real: 0.0
# Predicted: 0.024295713752508163;    Real: 1.0
# Predicted: 0.009320706129074097;    Real: 1.0
# Predicted: 0.016007201746106148;    Real: 0.0
# Predicted: 0.053413525223731995;    Real: 1.0
# Predicted: 0.01896250620484352;    Real: 0.0
# Predicted: 0.007013465743511915;    Real: 0.0
# Predicted: 0.011016406118869781;    Real: 0.0
# Predicted: 0.006900333799421787;    Real: 0.0
# Predicted: 0.026477791368961334;    Real: 1.0
# Predicted: 0.011727040633559227;    Real: 0.0
# Predicted: 0.01194954477250576;    Real: 0.0
# Predicted: 0.011765650473535061;    Real: 0.0
# Predicted: 0.012222465127706528;    Real: 0.0
# Predicted: 0.009762846864759922;    Real: 0.0
# Predicted: 0.017285136505961418;    Real: 1.0
# Predicted: 0.010883118025958538;    Real: 0.0
# Predicted: 0.01700885407626629;    Real: 0.0
# Predicted: 0.012509210966527462;    Real: 0.0
# Predicted: 0.031746141612529755;    Real: 0.0
# Predicted: 0.03671630471944809;    Real: 0.0
# Predicted: 0.00754496268928051;    Real: 0.0
# Predicted: 0.027942053973674774;    Real: 1.0
# Predicted: 0.005032339598983526;    Real: 1.0
# Predicted: 0.025410747155547142;    Real: 0.0
# Predicted: 0.01808200031518936;    Real: 0.0
# Predicted: 0.0109248673543334;    Real: 0.0
# Predicted: 0.010162082500755787;    Real: 0.0
# Predicted: 0.02386409044265747;    Real: 0.0
# Predicted: 0.0034702501725405455;    Real: 1.0
# Predicted: 0.0064744120463728905;    Real: 0.0
# Predicted: 0.012155257165431976;    Real: 0.0
# Predicted: 0.020292868837714195;    Real: 0.0
# Predicted: 0.007002720609307289;    Real: 0.0
# Predicted: 0.01818782649934292;    Real: 0.0
# Predicted: 0.027344804257154465;    Real: 0.0
# Predicted: 0.01025463081896305;    Real: 0.0
# Predicted: 0.006397713907063007;    Real: 0.0
# Predicted: 0.01804831065237522;    Real: 0.0
# Predicted: 0.010573376901447773;    Real: 0.0
# Predicted: 0.011866046115756035;    Real: 0.0
# Predicted: 0.006074420642107725;    Real: 0.0
# Predicted: 0.004308237694203854;    Real: 0.0
# Predicted: 0.019567733630537987;    Real: 0.0
# Predicted: 0.029747923836112022;    Real: 0.0
# Predicted: 0.009826852940022945;    Real: 1.0
# Predicted: 0.03297022357583046;    Real: 0.0
# Predicted: 0.024152342230081558;    Real: 0.0
# Predicted: 0.03234672173857689;    Real: 0.0
# Predicted: 0.009581496939063072;    Real: 0.0
# Predicted: 0.02111414074897766;    Real: 0.0
# Predicted: 0.013215606100857258;    Real: 1.0
# Predicted: 0.010494358837604523;    Real: 0.0
# Predicted: 0.02409203350543976;    Real: 0.0
# Predicted: 0.004489079117774963;    Real: 1.0
# Predicted: 0.020241323858499527;    Real: 0.0
# Predicted: 0.016308099031448364;    Real: 1.0
# Predicted: 0.0061327069997787476;    Real: 0.0
# Predicted: 0.034132275730371475;    Real: 0.0
# Predicted: 0.03655007481575012;    Real: 0.0
# Predicted: 0.006194219924509525;    Real: 0.0
# Predicted: 0.006301333662122488;    Real: 0.0
# Predicted: 0.012581868097186089;    Real: 0.0
# Predicted: 0.025112882256507874;    Real: 0.0
# Predicted: 0.027022073045372963;    Real: 0.0
# Predicted: 0.0056960443034768105;    Real: 0.0
# Predicted: 0.011741197668015957;    Real: 0.0
# Predicted: 0.007821052335202694;    Real: 0.0
# Predicted: 0.01042987871915102;    Real: 1.0
# Predicted: 0.0067785256542265415;    Real: 0.0
# Predicted: 0.02039973810315132;    Real: 0.0
# Predicted: 0.03305753692984581;    Real: 0.0
# Predicted: 0.04463595151901245;    Real: 1.0
# Predicted: 0.021386073902249336;    Real: 0.0
# Predicted: 0.02151065692305565;    Real: 0.0
# Predicted: 0.006853760220110416;    Real: 0.0
# Predicted: 0.006176219787448645;    Real: 0.0
# Predicted: 0.029015671461820602;    Real: 0.0
# Predicted: 0.019207192584872246;    Real: 0.0
# Predicted: 0.020864402875304222;    Real: 0.0
# Predicted: 0.006347334012389183;    Real: 1.0
# Predicted: 0.020825481042265892;    Real: 0.0
# Predicted: 0.019603196531534195;    Real: 0.0
# Predicted: 0.011877619661390781;    Real: 0.0
# Predicted: 0.010729361325502396;    Real: 0.0
# Predicted: 0.021032683551311493;    Real: 0.0
# Predicted: 0.006560979411005974;    Real: 0.0
# Predicted: 0.011579932644963264;    Real: 0.0
# Predicted: 0.008698994293808937;    Real: 1.0
# Predicted: 0.031452443450689316;    Real: 0.0
# Predicted: 0.01713753305375576;    Real: 0.0
# Predicted: 0.018110690638422966;    Real: 0.0
# Predicted: 0.009895882569253445;    Real: 1.0
# Predicted: 0.00966231431812048;    Real: 1.0
# Predicted: 0.007063742261379957;    Real: 0.0
# Predicted: 0.020923448726534843;    Real: 0.0
# Predicted: 0.02268492989242077;    Real: 0.0
# Predicted: 0.011678365990519524;    Real: 0.0
# Predicted: 0.018946750089526176;    Real: 0.0
# Predicted: 0.008637752383947372;    Real: 0.0
# Predicted: 0.020914573222398758;    Real: 0.0
# Predicted: 0.02938941866159439;    Real: 0.0
# Predicted: 0.020482422783970833;    Real: 0.0
# Predicted: 0.006437409669160843;    Real: 0.0
# Predicted: 0.02553471364080906;    Real: 0.0
# Predicted: 0.011562688276171684;    Real: 0.0
# Predicted: 0.010304098017513752;    Real: 0.0
# Predicted: 0.029663508757948875;    Real: 1.0
# Predicted: 0.01339046098291874;    Real: 0.0
# Predicted: 0.005906402599066496;    Real: 0.0
# Predicted: 0.029650019481778145;    Real: 0.0
# Predicted: 0.032551009207963943;    Real: 0.0
# Predicted: 0.01904015615582466;    Real: 0.0
# Predicted: 0.006457142531871796;    Real: 0.0
# Predicted: 0.011295457370579243;    Real: 0.0
# Predicted: 0.019535422325134277;    Real: 0.0
# Predicted: 0.003982536494731903;    Real: 0.0
# Predicted: 0.019756382331252098;    Real: 0.0
# Predicted: 0.0033543186727911234;    Real: 1.0
# Predicted: 0.03120269998908043;    Real: 0.0
# Predicted: 0.020270150154829025;    Real: 0.0
# Predicted: 0.006235616281628609;    Real: 0.0
# Predicted: 0.03345150873064995;    Real: 0.0
# Predicted: 0.01820698007941246;    Real: 1.0
# Predicted: 0.0036366796121001244;    Real: 0.0
# Predicted: 0.010899139568209648;    Real: 0.0
# Predicted: 0.01904452033340931;    Real: 1.0
# Predicted: 0.02881702408194542;    Real: 1.0
# Predicted: 0.0043875244446098804;    Real: 0.0
# Predicted: 0.006477154791355133;    Real: 0.0
# Predicted: 0.007055041380226612;    Real: 1.0
# Predicted: 0.03046575002372265;    Real: 0.0
# Predicted: 0.012573144398629665;    Real: 0.0
# Predicted: 0.0068286811001598835;    Real: 0.0
# Predicted: 0.0066990479826927185;    Real: 0.0
# Predicted: 0.020282858982682228;    Real: 0.0
# Predicted: 0.027548953890800476;    Real: 0.0
# Predicted: 0.020421599969267845;    Real: 0.0
# Predicted: 0.04569749906659126;    Real: 0.0
# Predicted: 0.011340774595737457;    Real: 0.0
# Predicted: 0.013237413950264454;    Real: 0.0
# Predicted: 0.034923434257507324;    Real: 0.0
# Predicted: 0.019750084728002548;    Real: 0.0
# Predicted: 0.013794112019240856;    Real: 0.0
# Predicted: 0.01119530014693737;    Real: 0.0
# Predicted: 0.012805761769413948;    Real: 0.0
# Predicted: 0.019083872437477112;    Real: 0.0
# Predicted: 0.013746567070484161;    Real: 0.0
# Predicted: 0.011519474908709526;    Real: 0.0
# Predicted: 0.01804419606924057;    Real: 0.0
# Predicted: 0.025742746889591217;    Real: 0.0
# Predicted: 0.017397945746779442;    Real: 1.0
# Predicted: 0.007220506202429533;    Real: 0.0
# Predicted: 0.01952064037322998;    Real: 0.0
# Predicted: 0.015090172179043293;    Real: 0.0
# Predicted: 0.019980669021606445;    Real: 0.0
# Predicted: 0.02957151271402836;    Real: 1.0
# Predicted: 0.0267950352281332;    Real: 1.0
# Predicted: 0.0064721121452748775;    Real: 0.0
# Predicted: 0.0070245033130049706;    Real: 0.0
# Predicted: 0.01888832449913025;    Real: 0.0
# Predicted: 0.02503734454512596;    Real: 1.0
# Predicted: 0.011850830167531967;    Real: 0.0
# Predicted: 0.022377436980605125;    Real: 0.0
# Predicted: 0.029693113639950752;    Real: 0.0
# Predicted: 0.033410415053367615;    Real: 0.0
# Predicted: 0.015716208145022392;    Real: 1.0
# Predicted: 0.01178862527012825;    Real: 0.0
# Predicted: 0.01726844348013401;    Real: 0.0
# Predicted: 0.03330950066447258;    Real: 1.0
# Predicted: 0.004619303159415722;    Real: 0.0
# Predicted: 0.026124313473701477;    Real: 0.0
# Predicted: 0.01910184882581234;    Real: 0.0
# Predicted: 0.02100258320569992;    Real: 0.0
# Predicted: 0.0054627652280032635;    Real: 0.0
# Predicted: 0.01790589466691017;    Real: 0.0
# Predicted: 0.01923235133290291;    Real: 0.0
# Predicted: 0.03512435033917427;    Real: 0.0
# Predicted: 0.020321691408753395;    Real: 0.0
# Predicted: 0.030146002769470215;    Real: 0.0
# Predicted: 0.03415924683213234;    Real: 0.0
# Predicted: 0.030643165111541748;    Real: 0.0
# Predicted: 0.013052030466496944;    Real: 0.0
# Predicted: 0.020526215434074402;    Real: 0.0
# Predicted: 0.03422167897224426;    Real: 0.0
# Predicted: 0.01032173540443182;    Real: 0.0
# Predicted: 0.020909300073981285;    Real: 0.0
# Predicted: 0.005918849725276232;    Real: 0.0
# Predicted: 0.013246297836303711;    Real: 0.0
# Predicted: 0.005290352273732424;    Real: 1.0
# Predicted: 0.022818932309746742;    Real: 0.0
# Predicted: 0.018362924456596375;    Real: 0.0
# Predicted: 0.03494756668806076;    Real: 0.0
# Predicted: 0.0043362039141356945;    Real: 0.0
# Predicted: 0.004592671059072018;    Real: 0.0
# Predicted: 0.018030691891908646;    Real: 0.0
# Predicted: 0.020673831924796104;    Real: 0.0
# Predicted: 0.04417482390999794;    Real: 0.0
# Predicted: 0.00904663372784853;    Real: 1.0
# Predicted: 0.011105620302259922;    Real: 0.0
# Predicted: 0.0034390874207019806;    Real: 0.0
# Predicted: 0.006868893280625343;    Real: 0.0
# Predicted: 0.011097191832959652;    Real: 0.0
# Predicted: 0.009867129847407341;    Real: 0.0
# Predicted: 0.02082720398902893;    Real: 0.0
# Predicted: 0.030346324667334557;    Real: 0.0
# Predicted: 0.03615735471248627;    Real: 0.0
# Predicted: 0.001243013422936201;    Real: 0.0
# Predicted: 0.005872182082384825;    Real: 0.0
# Predicted: 0.040357738733291626;    Real: 0.0
# Predicted: 0.025476297363638878;    Real: 1.0
# Predicted: 0.020231330767273903;    Real: 1.0
# Predicted: 0.03581475466489792;    Real: 0.0
# Predicted: 0.011853959411382675;    Real: 0.0
# Predicted: 0.013817530125379562;    Real: 0.0
# Predicted: 0.020995700731873512;    Real: 0.0
# Predicted: 0.018230050802230835;    Real: 0.0
# Predicted: 0.010551604442298412;    Real: 0.0
# Predicted: 0.010601183399558067;    Real: 0.0
# Predicted: 0.016750426962971687;    Real: 0.0
# Predicted: 0.0120142986997962;    Real: 0.0
# Predicted: 0.019390223547816277;    Real: 0.0
# Predicted: 0.018514078110456467;    Real: 0.0
# Predicted: 0.006307851988822222;    Real: 0.0
# Predicted: 0.012552234344184399;    Real: 0.0
# Predicted: 0.015353045426309109;    Real: 0.0
# Predicted: 0.006872012745589018;    Real: 1.0
# Predicted: 0.021228350698947906;    Real: 0.0
# Predicted: 0.023283572867512703;    Real: 1.0
# Predicted: 0.030840901657938957;    Real: 0.0
# Predicted: 0.03000381961464882;    Real: 0.0
# Predicted: 0.02032018080353737;    Real: 0.0
# Predicted: 0.012335298582911491;    Real: 0.0
# Predicted: 0.017104610800743103;    Real: 1.0
# Predicted: 0.0296337828040123;    Real: 0.0
# Predicted: 0.006529483012855053;    Real: 1.0
# Predicted: 0.0039068288169801235;    Real: 0.0
# Predicted: 0.020947569981217384;    Real: 0.0
# Predicted: 0.01886107213795185;    Real: 0.0
# Predicted: 0.0182962566614151;    Real: 0.0
# Predicted: 0.01810641586780548;    Real: 0.0
# Predicted: 0.012017865665256977;    Real: 0.0
# Predicted: 0.017142724245786667;    Real: 0.0
# Predicted: 0.024000216275453568;    Real: 0.0
# Predicted: 0.03273696079850197;    Real: 0.0
# Predicted: 0.0014810016145929694;    Real: 0.0
# Predicted: 0.020274639129638672;    Real: 0.0
# Predicted: 0.019034894183278084;    Real: 0.0
# Predicted: 0.007341446820646524;    Real: 0.0
# Predicted: 0.008049710653722286;    Real: 0.0
# Predicted: 0.022393757477402687;    Real: 0.0
# Predicted: 0.02051687054336071;    Real: 0.0
# Predicted: 0.015921087935566902;    Real: 1.0
# Predicted: 0.009262897074222565;    Real: 0.0
# Predicted: 0.04516855627298355;    Real: 0.0
# Predicted: 0.02783951722085476;    Real: 0.0
# Predicted: 0.006309181451797485;    Real: 0.0
# Predicted: 0.021486641839146614;    Real: 0.0
# Predicted: 0.02004442922770977;    Real: 0.0
# Predicted: 0.006704841274768114;    Real: 0.0
# Predicted: 0.022271882742643356;    Real: 0.0
# Predicted: 0.006446395069360733;    Real: 1.0
# Predicted: 0.012838026508688927;    Real: 0.0
# Predicted: 0.01911894790828228;    Real: 0.0
# Predicted: 0.021030060946941376;    Real: 0.0
# Predicted: 0.014961161650717258;    Real: 0.0
# Predicted: 0.006129244342446327;    Real: 1.0
# Predicted: 0.006666622590273619;    Real: 0.0
# Predicted: 0.006835944950580597;    Real: 0.0
# Predicted: 0.011270759627223015;    Real: 0.0
# Predicted: 0.013760371133685112;    Real: 1.0
# Predicted: 0.03366516903042793;    Real: 0.0
# Predicted: 0.011788948439061642;    Real: 1.0
# Predicted: 0.01868743635714054;    Real: 0.0
# Predicted: 0.010284291580319405;    Real: 1.0
# Predicted: 0.019080283120274544;    Real: 0.0
# Predicted: 0.029379434883594513;    Real: 0.0
# Predicted: 0.030519939959049225;    Real: 0.0
# Predicted: 0.003825234016403556;    Real: 1.0
# Predicted: 0.01007008831948042;    Real: 0.0
# Predicted: 0.018575629219412804;    Real: 1.0
# Predicted: 0.044683393090963364;    Real: 1.0
# Predicted: 0.022374451160430908;    Real: 0.0
# Predicted: 0.01894211582839489;    Real: 0.0
# Predicted: 0.020095858722925186;    Real: 0.0
# Predicted: 0.021191081032156944;    Real: 0.0
# Predicted: 0.012100670486688614;    Real: 0.0
# Predicted: 0.00645459396764636;    Real: 0.0
# Predicted: 0.019308511167764664;    Real: 0.0
# Predicted: 0.0063460892997682095;    Real: 0.0
# Predicted: 0.03055107593536377;    Real: 0.0
# Predicted: 0.02882510982453823;    Real: 0.0
# Predicted: 0.01815338432788849;    Real: 1.0
# Predicted: 0.020688531920313835;    Real: 0.0
# Predicted: 0.015835823491215706;    Real: 1.0
# Predicted: 0.01781540736556053;    Real: 0.0
# Predicted: 0.019269075244665146;    Real: 0.0
# Predicted: 0.036115020513534546;    Real: 0.0
# Predicted: 0.021650919690728188;    Real: 0.0
# Predicted: 0.025413878262043;    Real: 1.0
# Predicted: 0.01107221283018589;    Real: 0.0
# Predicted: 0.03286948800086975;    Real: 0.0
# Predicted: 0.020636677742004395;    Real: 0.0
# Predicted: 0.020687159150838852;    Real: 0.0
# Predicted: 0.024225888773798943;    Real: 1.0
# Predicted: 0.020804721862077713;    Real: 0.0
# Predicted: 0.021981874480843544;    Real: 0.0
# Predicted: 0.011605087667703629;    Real: 0.0
# Predicted: 0.011910895816981792;    Real: 0.0
# Predicted: 0.0220720823854208;    Real: 0.0
# Predicted: 0.026952529326081276;    Real: 1.0
# Predicted: 0.03775526583194733;    Real: 0.0
# Predicted: 0.011102499440312386;    Real: 0.0
# Predicted: 0.02242373675107956;    Real: 0.0
# Predicted: 0.006208228413015604;    Real: 1.0
# Predicted: 0.015100892633199692;    Real: 1.0
# Predicted: 0.03835611417889595;    Real: 0.0
# Predicted: 0.03552713990211487;    Real: 0.0
# Predicted: 0.017495132982730865;    Real: 0.0
# Predicted: 0.02017221972346306;    Real: 0.0
# Predicted: 0.022771598771214485;    Real: 0.0
# Predicted: 0.030179115012288094;    Real: 0.0
# Predicted: 0.007188062183558941;    Real: 0.0
# Predicted: 0.011332704685628414;    Real: 0.0
# Predicted: 0.02202868089079857;    Real: 0.0
# Predicted: 0.017948895692825317;    Real: 0.0
# Predicted: 0.01673312671482563;    Real: 0.0
# Predicted: 0.00429655984044075;    Real: 0.0
# Predicted: 0.03071952983736992;    Real: 0.0
# Predicted: 0.0025057741440832615;    Real: 0.0
# Predicted: 0.012443926185369492;    Real: 0.0
# Predicted: 0.007438251283019781;    Real: 0.0
# Predicted: 0.02214142493903637;    Real: 0.0
# Predicted: 0.01519681140780449;    Real: 1.0
# Predicted: 0.022744378075003624;    Real: 0.0
# Predicted: 0.03134530037641525;    Real: 1.0
# Predicted: 0.010773015208542347;    Real: 0.0
# Predicted: 0.012856405228376389;    Real: 0.0
# Predicted: 0.03207727521657944;    Real: 0.0
# Predicted: 0.029037777334451675;    Real: 0.0
# Predicted: 0.010294416919350624;    Real: 0.0
# Predicted: 0.01902175508439541;    Real: 0.0
# Predicted: 0.024831393733620644;    Real: 0.0
# Predicted: 0.03108757920563221;    Real: 0.0
# Predicted: 0.0031609598081558943;    Real: 1.0
# Predicted: 0.010700162500143051;    Real: 0.0
# Predicted: 0.022362973541021347;    Real: 0.0
# Predicted: 0.011862043291330338;    Real: 0.0
# Predicted: 0.021499909460544586;    Real: 0.0
# Predicted: 0.010725398547947407;    Real: 0.0
# Predicted: 0.028141705319285393;    Real: 0.0
# Predicted: 0.02146330289542675;    Real: 0.0
# Predicted: 0.045099981129169464;    Real: 1.0
# Predicted: 0.011463715694844723;    Real: 0.0
# Predicted: 0.01893950067460537;    Real: 0.0
# Predicted: 0.004112260416150093;    Real: 0.0
# Predicted: 0.012648122385144234;    Real: 0.0
# Predicted: 0.01108741108328104;    Real: 0.0
# Predicted: 0.02160627953708172;    Real: 0.0
# Predicted: 0.007720754016190767;    Real: 0.0
# Predicted: 0.033962611109018326;    Real: 0.0
# Predicted: 0.018740098923444748;    Real: 0.0
# Predicted: 0.012074068188667297;    Real: 0.0
# Predicted: 0.020198022946715355;    Real: 0.0
# Predicted: 0.022293584421277046;    Real: 0.0
# Predicted: 0.009533942677080631;    Real: 1.0
# Predicted: 0.018795007839798927;    Real: 0.0
# Predicted: 0.010498488321900368;    Real: 0.0
# Predicted: 0.03957878425717354;    Real: 0.0
# Predicted: 0.024983426555991173;    Real: 0.0
# Predicted: 0.011726095341145992;    Real: 0.0
# Predicted: 0.006030077580362558;    Real: 0.0
# Predicted: 0.01173677109181881;    Real: 1.0
# Predicted: 0.019836707040667534;    Real: 0.0
# Predicted: 0.009583315812051296;    Real: 1.0
# Predicted: 0.01924462430179119;    Real: 0.0
# Predicted: 0.014193866401910782;    Real: 1.0
# Predicted: 0.02823464199900627;    Real: 0.0
# Predicted: 0.023582005873322487;    Real: 0.0
# Predicted: 0.0225457102060318;    Real: 0.0
# Predicted: 0.034776199609041214;    Real: 0.0
# Predicted: 0.006941155064851046;    Real: 0.0
# Predicted: 0.01230138260871172;    Real: 0.0
# Predicted: 0.02818993292748928;    Real: 0.0
# Predicted: 0.01878519542515278;    Real: 0.0
# Predicted: 0.025599615648388863;    Real: 1.0
# Predicted: 0.019844356924295425;    Real: 0.0
# Predicted: 0.027599994093179703;    Real: 0.0
# Predicted: 0.017599474638700485;    Real: 0.0
# Predicted: 0.010885325260460377;    Real: 0.0
# Predicted: 0.03605249524116516;    Real: 0.0
# Predicted: 0.006127187516540289;    Real: 0.0
# Predicted: 0.018575012683868408;    Real: 0.0
# Predicted: 0.009772767312824726;    Real: 0.0
# Predicted: 0.01686931774020195;    Real: 1.0
# Predicted: 0.023634128272533417;    Real: 0.0
# Predicted: 0.020948579534888268;    Real: 0.0
# Predicted: 0.006709396839141846;    Real: 0.0
# Predicted: 0.020086631178855896;    Real: 0.0
# Predicted: 0.028070466592907906;    Real: 1.0
# Predicted: 0.011791519820690155;    Real: 0.0
# Predicted: 0.00639685895293951;    Real: 0.0
# Predicted: 0.01871035248041153;    Real: 0.0
# Predicted: 0.027620183303952217;    Real: 1.0
# Predicted: 0.011002695187926292;    Real: 0.0
# Predicted: 0.020065881311893463;    Real: 0.0
# Predicted: 0.0166939627379179;    Real: 0.0
# Predicted: 0.006299551110714674;    Real: 0.0
# Predicted: 0.004622845444828272;    Real: 0.0
# Predicted: 0.022247424349188805;    Real: 0.0
# Predicted: 0.021463824436068535;    Real: 0.0
# Predicted: 0.014885555021464825;    Real: 0.0
# Predicted: 0.03289162367582321;    Real: 0.0
# Predicted: 0.01973176747560501;    Real: 0.0
# Predicted: 0.027165275067090988;    Real: 0.0
# Predicted: 0.020605899393558502;    Real: 0.0
# Predicted: 0.0064247287809848785;    Real: 0.0
# Predicted: 0.01901230961084366;    Real: 0.0
# Predicted: 0.020067820325493813;    Real: 0.0
# Predicted: 0.027027113363146782;    Real: 1.0
# Predicted: 0.006049236282706261;    Real: 0.0
# Predicted: 0.009337276220321655;    Real: 0.0
# Predicted: 0.011417865753173828;    Real: 0.0
# Predicted: 0.030852647498250008;    Real: 0.0
# Predicted: 0.018998438492417336;    Real: 0.0
# Predicted: 0.010824124328792095;    Real: 0.0
# Predicted: 0.021274568513035774;    Real: 0.0
# Predicted: 0.021318726241588593;    Real: 0.0
# Predicted: 0.006362678483128548;    Real: 0.0
# Predicted: 0.020213115960359573;    Real: 1.0
# Predicted: 0.02719927951693535;    Real: 1.0
# Predicted: 0.01911788433790207;    Real: 0.0
# Predicted: 0.018067140132188797;    Real: 0.0
# Predicted: 0.010290399193763733;    Real: 0.0
# Predicted: 0.0037139407359063625;    Real: 1.0
# Predicted: 0.0036241470370441675;    Real: 1.0
# Predicted: 0.006870398763567209;    Real: 0.0
# Predicted: 0.011631601490080357;    Real: 0.0
# Predicted: 0.003666046541184187;    Real: 1.0
# Predicted: 0.012716732919216156;    Real: 0.0
# Predicted: 0.0063313874416053295;    Real: 0.0
# Predicted: 0.01304700132459402;    Real: 0.0
# Predicted: 0.022358646616339684;    Real: 0.0
# Predicted: 0.03668695315718651;    Real: 0.0
# Predicted: 0.019435780122876167;    Real: 0.0
# Predicted: 0.01941288448870182;    Real: 0.0
# Predicted: 0.01873731054365635;    Real: 0.0
# Predicted: 0.020681288093328476;    Real: 0.0
# Predicted: 0.020203543826937675;    Real: 0.0
# Predicted: 0.03223004564642906;    Real: 0.0
# Predicted: 0.04317816346883774;    Real: 1.0
# Predicted: 0.01873389072716236;    Real: 0.0
# Predicted: 0.011119292117655277;    Real: 0.0
# Predicted: 0.018700191751122475;    Real: 0.0
# Predicted: 0.020589526742696762;    Real: 0.0
# Predicted: 0.006686061155050993;    Real: 0.0
# Predicted: 0.029707681387662888;    Real: 0.0
# Predicted: 0.0070129442028701305;    Real: 0.0
# Predicted: 0.021500863134860992;    Real: 0.0
# Predicted: 0.017526226118206978;    Real: 0.0
# Predicted: 0.010926824994385242;    Real: 0.0
# Predicted: 0.04177725687623024;    Real: 0.0
# Predicted: 0.002536133863031864;    Real: 0.0
# Predicted: 0.02767839841544628;    Real: 1.0
# Predicted: 0.011853053234517574;    Real: 0.0
# Predicted: 0.012494205497205257;    Real: 0.0
# Predicted: 0.02992599457502365;    Real: 0.0
# Predicted: 0.029604248702526093;    Real: 0.0
# Predicted: 0.01966105028986931;    Real: 0.0
# Predicted: 0.034656036645174026;    Real: 0.0
# Predicted: 0.011443226598203182;    Real: 0.0
# Predicted: 0.012060368433594704;    Real: 0.0
# Predicted: 0.010324278846383095;    Real: 0.0
# Predicted: 0.033281657844781876;    Real: 0.0
# Predicted: 0.006389228627085686;    Real: 0.0
# Predicted: 0.01560817938297987;    Real: 0.0
# Predicted: 0.029048550873994827;    Real: 0.0
# Predicted: 0.016991369426250458;    Real: 1.0
# Predicted: 0.014344005845487118;    Real: 0.0
# Predicted: 0.02131274901330471;    Real: 0.0
# Confusion Matrix:
# [[848   0]
#  [152   0]]
# 32/32 - 2s - 71ms/step - accuracy: 0.8480 - loss: 0.6592 - precision: 0.0000e+00 - recall: 0.0000e+00
#
# Test Accuracy: 0.8479999899864197
